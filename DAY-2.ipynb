# %%
import pandas as pd
import numpy as np

# %%
d=pd.read_csv("E:\Machine\DAY-2\diabetes.csv")
#d is a dataframe for the diabetes dataset

# %%
print(d)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
d.head()
#display 1st 5 rows
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
d.tail()
#display last 5 rows
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
d.isnull().sum()
#print sum of all null values
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
d.value_counts('Glucose')
#display count of each values
# Out:
# Glucose
# 99     17
# 100    17
# 129    14
# 125    14
# 106    14
#        ..
# 169     1
# 61      1
# 178     1
# 177     1
# 199     1
# Length: 136, dtype: int64

# %%
d.info
#Info about whole data set is given
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
d.shape
#No. of rows and columns is diaplayed
# Out:
# (768, 9)

# %%
d.rename(columns={'BMI':'BodyMassIndex'})
#BMI is renamed as BodyMassIndex
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              6      148             72             35        0
# 1              1       85             66             29        0
# 2              8      183             64              0        0
# 3              1       89             66             23       94
# 4              0      137             40             35      168
# ..           ...      ...            ...            ...      ...
# 763           10      101             76             48      180
# 764            2      122             70             27        0
# 765            5      121             72             23      112
# 766            1      126             60              0        0
# 767            1       93             70             31        0
#
#      BodyMassIndex  DiabetesPedigreeFunction  Age  Outcome
# 0             33.6                     0.627   50        1
# 1             26.6                     0.351   31        0
# ...
